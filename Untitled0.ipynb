# %% [markdown]
# <a href="https://colab.research.google.com/github/GustasAndre/case_produtos/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Etapa 01) Leia o arquivo e inspecione os dados
# Pesquisar o mercado apontando os produtos que já existem hoje e seus diferenciais. É
# importante apresentar de forma clara os concorrentes diretos e indiretos, e destacar
# seus diferenciais e pontos fortes.
# 1. Leia o dataset
# 2. Utilize o describe para verificar a distribuição dos dados
# Desafio: Prepare seu dataset para modelagem de dados 4
# 3. Analise o tipo dos dados
#   💡 Dica:
#         1. Leia o dataset
#         2. Utilize o describe para verificar a distribuição dos dados
#         3. Analise o tipo dos dados

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
#importando o arquivo CSV
df = pd.read_csv('/content/data.csv', encoding='latin1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
#Verificando a distribuição dos dados
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
#Analisando os tipos de dados

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %% [markdown]
# # Etapa 02) Valores faltantes na identificação do cliente
# 💡 Dica: Se sim, remova estas observações.
# 1. Verifique os valores nulos com o isna e utilize a função sum para a somar
# a quantidade de nulos
# 2. Utilize a função dropna para remover os nulos

# %%
#Contagem de valores nulos
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
#Eliminar colunas com valores nulos
df_clear = df.dropna()
df_clear.isna().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %% [markdown]
# # Etapa 03) Preços unitários e quantidade de produtos iguais ou inferior a 0
# 💡 Dica: Se sim, remova estas observações.
# 1. Realize um filtro para verificar se existem dados nulos ou menor que zero
# na coluna de preços
# 2. Filtre o dataset apenas para conter preços acima de zero
# 3. Realize um filtro para verificar se existem dados nulos ou menor que zero
# na coluna de quantidade
# 4. Filtre o dataset apenas para conter quantidade acima de zero

# %%
#Verificando se há dados nulos na coluna de preços
null_prices = df['UnitPrice'].isna().sum()
null_prices
# Out:
# 0

# %%
#Verificando se há valores menores que 0 na coluna preços
negative_prices = (df['UnitPrice'] <= 0).sum()
negative_prices
# Out:
# 2517

# %%
#Verificando se há dados nulos na coluna de Quantidade
null_qt = df['Quantity'].isna().sum()
null_qt
# Out:
# 0

# %%
#Verificando se há valores menores que 0 na coluna Quantidade
negative_qt = (df['Quantity'] <= 0).sum()
negative_qt
# Out:
# 10624

# %%
#Filtrando o dataset para conter dados acima de 0 nas colunas perço e quantidade
df_new = df[(df['Quantity']>0) & (df['UnitPrice']>0)]
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 530104 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    530104 non-null  object
#  1   StockCode    530104 non-null  object
#  2   Description  530104 non-null  object
#  3   Quantity     530104 non-null  int64
#  4   InvoiceDate  530104 non-null  object
#  5   UnitPrice    530104 non-null  float64
#  6   CustomerID   397884 non-null  float64
#  7   Country      530104 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 36.4+ MB

# %% [markdown]
# # Etapa 04) Verifique se existem linhas duplicadas
# 💡 Dica: Se sim, remova estas observações (pois não faz sentido uma mesma
# compra para o mesmo cliente no mesmo horário, com mesmos valores etc.)
# 1. Verifique se tem linhas duplicadas com a função duplicated
# 2. Drope as linhas duplicadas

# %%
#Verificar se existe linha duplicada
df_duplicate = df_new.duplicated()
#dropar linhas duplicadas
df_new_duplicate = df_duplicate.drop_duplicates()
df_new_duplicate.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 2 entries, 0 to 517
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 2 non-null      bool
# dtypes: bool(1)
# memory usage: 18.0 bytes

# %% [markdown]
# # Etapa 05) Tipos de dados da coluna
# 💡 Dica:
# 1. Corrija o tipo de dado do CustomerID
# 2. Corrija o tipo de dado da InvoiceDate
# Coluna Tipo esperado:
#   InvoiceNo object / str
#   StockCode object / str
#   Description object / str
#   Quantity int
#   InvoiceDate datetime
#   UnitPrice float
#   CustomerID int
#   Country object / str

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 530104 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    530104 non-null  object
#  1   StockCode    530104 non-null  object
#  2   Description  530104 non-null  object
#  3   Quantity     530104 non-null  int64
#  4   InvoiceDate  530104 non-null  object
#  5   UnitPrice    530104 non-null  float64
#  6   CustomerID   397884 non-null  float64
#  7   Country      530104 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 36.4+ MB

# %%
# Preencher os dados non-null
df_new = df_new.dropna(subset=['CustomerID'])

#transformar os dados em inteiros da coluna CustomerID
df_new['CustomerID'] = df_new['CustomerID'].astype('int')

#transformar os dados em inteiros da coluna InvoiceDate
df_new['InvoiceDate'] = pd.to_datetime(df_new['InvoiceDate'])

# Verificar informações do DataFrame atualizadas
df_new.info()
# Out:
# <ipython-input-174-789bc7a79c57>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['CustomerID'] = df_new['CustomerID'].astype('int')
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 397884 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    397884 non-null  object
#  1   StockCode    397884 non-null  object
#  2   Description  397884 non-null  object
#  3   Quantity     397884 non-null  int64
#  4   InvoiceDate  397884 non-null  datetime64[ns]
#  5   UnitPrice    397884 non-null  float64
#  6   CustomerID   397884 non-null  int64
#  7   Country      397884 non-null  object
# ...

# %% [markdown]
# # Etapa 06) Tratando os outliers
# Dica: Vamos considerar estes valores como erro.Visualize os outliers e
# remova os outliers extremos em que a quantidade do item na compra é
# superior a 10.000, e o preço unitário é maior que 5.000.

# %%
#Removendo os valores com erros:
df_filter = df_new[(df_new['Quantity'] <= 10000) & (df_new['UnitPrice'] <= 5000)]

df_filter.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  397881.000000  397881.000000  397881.000000
# mean       12.598242       3.096038   15294.426122
# std        42.886053      17.938862    1713.140274
# min         1.000000       0.001000   12347.000000
# 25%         2.000000       1.250000   13969.000000
# 50%         6.000000       1.950000   15159.000000
# 75%        12.000000       3.750000   16795.000000
# max      4800.000000    4161.060000   18287.000000

# %% [markdown]
# # Etapa 07) Crie uma coluna adicional
# Dica: Utilize as colunas Quantity e UnitPrice. Crie uma coluna adicional
# com o preço total da compra

# %%
#Criar uma coluna nova com o preço total da compra

df_filter ['TotalCompra'] = df_filter['Quantity'] * df_filter['UnitPrice']

df_filter.head()
# Out:
# <ipython-input-176-72f7c41727c5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filter ['TotalCompra'] = df_filter['Quantity'] * df_filter['UnitPrice']
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalCompra
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom        15.30
# ...

# %% [markdown]
# # Etapa 08) Última data
# Dica: Utilize a função max(). Calcule a data da última compra no dataset
# como um todo, pois vamos utilizar este valor como data de comparação
# para cálculo da recência

# %%
#Data da última compra
df_ultima_compra = df_filter['InvoiceDate'].max()

df_ultima_compra
# Out:
# Timestamp('2011-12-09 12:50:00')

# %% [markdown]
# # Etapa 09) Plotando gráficos
#
#
# *   Top 10 países com maior valor em vendas
# *   Top 10 produtos mais vendidos
# *   Valor de venda total por mês
# *   Valor de venda total por mês e por país (considere apenas os top 10)

# %%
#Valore de vendas por país:
sales_country = df_filter.groupby('Country')['TotalCompra'].sum().sort_values(ascending= False)

#Selecionar Top 10:
top_country = sales_country.head(10)

#Plotar gráfico:
plt.figure(figsize=(10,6))
top_country.plot(kind='bar',color= 'blue')
plt.title('Top 10 países com maior valor em vendas')
plt.xlabel('País')
plt.ylabel('Valor total em vendas')
plt.show()

# %%
#top 10 produtos mais vendidos:
sales_products = df_filter.groupby('Description')['Quantity'].sum().sort_values(ascending= False)

#Selecionar Top 10:
top_products = sales_products.head(10)

#Plotar gráfico:
plt.figure(figsize=(10,6))
top_products.plot(kind='bar',color= 'blue')
plt.title('Top 10 produtos mais vendidos')
plt.xlabel('Produto')
plt.ylabel('Quantidade')
plt.show()

# %%
#Calcular valor de vendas por mês
sales_per_month = df_filter.groupby(df_filter['InvoiceDate'].dt.to_period('M'))['TotalCompra'].sum()

#Plotar gráfico
plt.figure(figsize=(12,7))
sales_per_month.plot(kind='line',color= 'blue')
plt.title('Valor de vendas por mês')
plt.xlabel('Mês')
plt.ylabel('Valor')
plt.show()

# %%
# Selecionar os top 10 países com maior valor em vendas
top_10_countries = df_filter.groupby('Country')['TotalCompra'].sum().nlargest(10)

# Filtrar o DataFrame para incluir apenas os top 10 países
df_top_10_countries = df_filter[df_filter['Country'].isin(top_10_countries.index)]

# Criar a tabela dinâmica para o valor de vendas por mês e por país
sales_per_month_country = df_top_10_countries.groupby([df_top_10_countries['InvoiceDate'].dt.to_period('M'), 'Country'])['TotalCompra'].sum().unstack()

# Plotar o gráfico
plt.figure(figsize=(12, 8))
sales_per_month_country.plot(kind='line', marker='o')
plt.title('Valor de Venda Total por Mês e por País (Top 10)')
plt.xlabel('Mês')
plt.ylabel('Valor Total de Vendas')
plt.legend(title='País', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

# %% [markdown]
# # Etapa 10) Cálculo do RFM
# 💡 Dica: Agrupe os dados por cliente e pedido/compra (InvoiceNo) e obtenha a
# data e o preço total do pedido.
# Com isso, agrupe novamente apenas por cliente e calcule o RFM, onde:
# - R é a recência, diferença em dias da última compra do cliente e da última
# compra disponível no conjunto de dados, que calcularam previamente.
# - F é a frequência, ou seja, a quantidade de compras feitas pelo cliente;
# - M é o ticket médio, ou seja, a média das compras feitas pelo cliente.

# %%
#Calculo da recorrência (R)
recency =df_filter.groupby('CustomerID')['InvoiceDate'].max() #data da última compra de cada cliente
recency = (df_ultima_compra - recency).dt.days

#Calcular a frequencia de compras de cada cliente (F)
frequency = df_filter.groupby('CustomerID')['InvoiceNo'].nunique()

#Calcular o total de gastos por cliente
total_client = df_filter.groupby('CustomerID')['TotalCompra'].sum()

#Calcular o ticket médio (M):
average_spent = total_client / frequency

df_rfm = pd.DataFrame({'Recency':recency,'Frequency':frequency,'Monetary':average_spent})

df_rfm.head()
# Out:
#             Recency  Frequency     Monetary
# CustomerID
# 12347             1          7   615.714286
# 12348            74          4   449.310000
# 12349            18          1  1757.550000
# 12350           309          1   334.400000
# 12352            35          8   313.255000
